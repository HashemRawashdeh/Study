# %% [markdown]
# # Problem Statement:
# ---
# This is a kaggle competetion, in which the goal is to recognize hand-written digits using convolutional neural networks.

# %% [markdown]
# # Importing Libraries/Dataset:
# ---

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import datetime
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
x = df_train.iloc[:, 1:].values.reshape(42000, 28,28)
y = df_train.iloc[:,0].values

# %%
x_test = df_test.values.reshape(28000, 28,28)

# %% [markdown]
# # Visualizing The Data:
# ---

# %%
m = x.shape[0]

fig, ax = plt.subplots(5,5,figsize=(5,5))
fig.tight_layout(pad=0.1)

for i, ax in enumerate(ax.flat):
    rand = np.random.randint(m)
    
    ax.imshow(x[rand].reshape(28,28))
    ax.set_title(y[rand])
    ax.set_axis_off()

# %% [markdown]
# # Preparing The Data For Training:
# ---

# %%
# Normalizing The Data:
x = x/255
x_test = x_test/255
# Splitting The Data Into Training/Validation:
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size=0.1, random_state=1)

# %%
# Checking the shapes of the data:
print(f'x_train shape: {x_train.shape}')
print(f'x_valid shape: {x_valid.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'y_valid shape: {y_valid.shape}')
# Out:
# x_train shape: (37800, 28, 28)
# x_valid shape: (4200, 28, 28)
# y_train shape: (37800,)
# y_valid shape: (4200,)

# %% [markdown]
# # Bulding The Model:
# ---

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D, Lambda, MaxPooling2D # convolution layers
from keras.layers import Dense, Dropout, Flatten # core layers
from keras.layers import BatchNormalization

model=Sequential()

model.add(Conv2D(filters=64, kernel_size = (3,3), activation="relu", input_shape=(28,28,1)))
model.add(Conv2D(filters=64, kernel_size = (3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(filters=128, kernel_size = (3,3), activation="relu"))
model.add(Conv2D(filters=128, kernel_size = (3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())    

model.add(Conv2D(filters=256, kernel_size = (3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
    
model.add(Flatten())
model.add(Dense(512,activation="relu"))
    
model.add(Dense(10,activation="softmax"))


model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 26, 26, 64)        640
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 12, 12, 64)       256
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 10, 10, 128)       73856
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 4, 4, 128)        512
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 2, 2, 256)         295168
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 1, 1, 256)        1024
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 692,682
# Trainable params: 691,786
# Non-trainable params: 896
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics='acc')

# %% [markdown]
# # Data Augmentation
# ---

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.01, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

train_gen = datagen.flow(x_train.reshape(37800,28,28,1), y_train, batch_size=128)
valid_gen = datagen.flow(x_valid.reshape(4200,28,28,1), y_valid, batch_size=128)

# %% [markdown]
# # Training The Model:
# ---

# %%
history = model.fit_generator(train_gen, 
                              epochs = 100, 
                              validation_data = valid_gen
                              )
# Out:
# Epoch 1/100
# 296/296 [==============================] - 14s 43ms/step - loss: 0.0723 - acc: 0.9817 - val_loss: 0.0228 - val_acc: 0.9938
# Epoch 2/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0337 - acc: 0.9899 - val_loss: 0.0180 - val_acc: 0.9940
# Epoch 3/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0279 - acc: 0.9913 - val_loss: 0.0281 - val_acc: 0.9936
# Epoch 4/100
# 296/296 [==============================] - 13s 45ms/step - loss: 0.0230 - acc: 0.9925 - val_loss: 0.0236 - val_acc: 0.9955
# Epoch 5/100
# 296/296 [==============================] - 18s 60ms/step - loss: 0.0212 - acc: 0.9938 - val_loss: 0.0262 - val_acc: 0.9943
# Epoch 6/100
# 296/296 [==============================] - 13s 43ms/step - loss: 0.0190 - acc: 0.9942 - val_loss: 0.0188 - val_acc: 0.9952
# Epoch 7/100
# 296/296 [==============================] - 13s 45ms/step - loss: 0.
100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0050 - acc: 0.9983 - val_loss: 0.0328 - val_acc: 0.9943
# Epoch 76/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0055 - acc: 0.9983 - val_loss: 0.0420 - val_acc: 0.9943
# Epoch 77/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0046 - acc: 0.9984 - val_loss: 0.0349 - val_acc: 0.9943
# Epoch 78/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0046 - acc: 0.9986 - val_loss: 0.0247 - val_acc: 0.9940
# Epoch 79/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0044 - acc: 0.9987 - val_loss: 0.0246 - val_acc: 0.9957
# Epoch 80/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0033 - acc: 0.9989 - val_loss: 0.0333 - val_acc: 0.9943
# Epoch 81/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0055 - acc: 0.9985 - val_loss: 0.0381 - val_acc: 0.9938
# Epoch 82/100
# 296/296 [==============================] - 13s 43ms/step - loss: 0.0055 - acc: 0.9982 - val_loss: 0.0264 - val_acc: 0.9950
# Epoch 83/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0043 - acc: 0.9986 - val_loss: 0.0344 - val_acc: 0.9943
# Epoch 84/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0050 - acc: 0.9985 - val_loss: 0.0281 - val_acc: 0.9945
# Epoch 85/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0034 - acc: 0.9988 - val_loss: 0.0381 - val_acc: 0.9933
# Epoch 86/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0053 - acc: 0.9985 - val_loss: 0.0331 - val_acc: 0.9938
# Epoch 87/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0042 - acc: 0.9988 - val_loss: 0.0312 - val_acc: 0.9950
# Epoch 88/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0065 - acc: 0.9982 - val_loss: 0.0362 - val_acc: 0.9940
# Epoch 89/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0035 - acc: 0.9986 - val_loss: 0.0263 - val_acc: 0.9960
# Epoch 90/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0039 - acc: 0.9986 - val_loss: 0.0309 - val_acc: 0.9957
# Epoch 91/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0033 - acc: 0.9989 - val_loss: 0.0337 - val_acc: 0.9952
# Epoch 92/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0022 - acc: 0.9993 - val_loss: 0.0345 - val_acc: 0.9943
# Epoch 93/100
# 296/296 [==============================] - 13s 45ms/step - loss: 0.0041 - acc: 0.9987 - val_loss: 0.0247 - val_acc: 0.9955
# Epoch 94/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0038 - acc: 0.9989 - val_loss: 0.0409 - val_acc: 0.9936
# Epoch 95/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0053 - acc: 0.9982 - val_loss: 0.0335 - val_acc: 0.9945
# Epoch 96/100
# 296/296 [==============================] - 13s 45ms/step - loss: 0.0053 - acc: 0.9984 - val_loss: 0.0340 - val_acc: 0.9931
# Epoch 97/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0041 - acc: 0.9985 - val_loss: 0.0297 - val_acc: 0.9943
# Epoch 98/100
# 296/296 [==============================] - 13s 44ms/step - loss: 0.0040 - acc: 0.9988 - val_loss: 0.0246 - val_acc: 0.9952
# Epoch 99/100
# 296/296 [==============================] - 13s 43ms/step - loss: 0.0030 - acc: 0.9990 - val_loss: 0.0387 - val_acc: 0.9952
# Epoch 100/100
# 296/296 [==============================] - 13s 45ms/step - loss: 0.0030 - acc: 0.9989 - val_loss: 0.0256 - val_acc: 0.9955

# %% [markdown]
# # Visualizing The Performance:
# ---

# %%
acc = history.history['acc']
valid_acc = histoacc = history.history['acc']
valid_acc = history.history['val_acc']
plt.plot(range(1,101), acc, label='Training Accuracy')
plt.plot(range(1,101), valid_acc, label='Validation Accuracy')
plt.legend()

# %% [markdown]
# # Creating Submission CSV:
# ---

# %%
predictions = model.predict(x_test)
# Out:
# 875/875 [==============================] - 3s 3ms/step

# %%
df = pd.DataFrame({'ImageId':range(1,28001),
                   'Label': [prediction.argmax() for prediction in predictions]})
df.set_index('ImageId', inplace=True)
df
# Out:
#          Label
# ImageId
# 1            2
# 2            0
# 3            9
# 4            0
# 5            3
# ...        ...
# 27996        9
# 27997        7
# 27998        3
# 27999        9
# 28000        2
#
# [28000 rows x 1 columns]

# %%
df.to_csv('digit_recognizer_submission.csv')
