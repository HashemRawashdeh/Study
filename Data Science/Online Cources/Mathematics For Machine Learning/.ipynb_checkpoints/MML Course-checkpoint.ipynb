# %% [markdown]
# # **Mathematics For Machine Learning**
# This specialization is presented by a very prestegous university (in the top 10 worldwide), and serves to bridge the mathematical gap between someone's knowledge and the ability to jump into field-specific ML Courses, and it covers the following:
# * Linear Algebra
# * Multivariate Calculus
# * Optimization
# * Some Probability and Statistics
# * Miscellenous ML specific Mathematical concepts
#
# As an Electrical Engineering student, I have studied numeruos mathematical courses such as calculus(1,2,3), applied mathematics, numerical methods, probability, differential equations, and more. Therefore, most of the topics covered in this specialization will serve as a refresher rather than a source of new knowledge. I will accompany this journey by some books that I find useful, and with practical exercises anytime I see a good enough chance for it.

# %% [markdown]
# # **Course One | Linear Algebra**
# The lecturer does everything by hand, and I will go along with him mostly by coding since I am already familiar with manually solving such problems. I will solve by hand whenever I see the need to, and perhabs even uploading an image of my hand writter notes.

# %% [markdown]
# ## **Week One**
# In this first module we look at how linear algebra is relevant to machine learning and data science. Then we'll wind up the module with an initial introduction to vectors. Throughout, we're focussing on developing your mathematical intuition, not of crunching through algebra or doing long pen-and-paper examples. For many of these operations, there are callable functions in Python that can do the adding up - the point is to appreciate what they do and how they work so that, when things go wrong or there are special cases, you can understand why and what to do.
#
# **Learning Objictives**:
# * Recall how machine learning and vectors and matrices are related
# * Interpret how changes in the model parameters affect the quality of the fit to the training data
# * Recognize that variations in the model parameters are vectors on the response surface - that vectors are a generic concept not limited to a physical real space
# * Use substitution / elimination to solve a fairly easy linear algebra problem
# * Understand how to add vectors and multiply by a scalar number

# %% [markdown]
# ### **The Relationship Between Machine Learning, Linear Algebra, and Vectors and Matrices**

# %% [markdown]
# Here the lecturer conceptually descriped two mathematical problems faced in machine learning:
# 1. Solving systems of linear equations
# 2. Fitting a curve into a data distribution by maximizing some parameters
#
# The First quiz was a taste of what this specialization is going to cover. An optimization problem of how to minimize the SSR by creating a mean, std vector that is moving towards the global minimum by going with the directional derivitive that makes a right angle with the contuer lines. This short quiz showed how some concepts of multivariate calculus and linear algebra play a cardinal rule in machine learning.
#
# The second quiz serves as a refresher in solving systems of linear equations, and since I'm familiar with this topic, I will do the basic ones in my mind, and pick the ones I see a benifit in practicing them in code here:

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Solve the following system of equations by the inverse method:

c = np.array([[-2,2],[5,3]])  # Coefficient Matrix
v = np.array([20,6])          # constants vector

c_inv = np.linalg.inv(c)

solution = c_inv @ v          # Matrix Product
solution

# The benifit of doing this simple problem is getting familiar with matrix inverse and multiplication using numpy
# Out:
# array([-3.,  7.])

# %%
# Solve the following system of linear equations:

c = np.array([[3,-2,1],[1,1,1],[3,-2,-1]])  # Coefficient Matrix
v = np.array([7,2,3])                       # constants vector

solution = np.linalg.solve(c,v)
solution

# The point of doing this problem is getting familiar with how numpy solves systems of linear equations
# Out:
# array([ 1., -1.,  2.])

# %% [markdown]
# #### **Vectors**

# %% [markdown]
# **Video:**
#
# Expanded the definition of a vector as a thing in space that has a specific magnitude and points to a specific direction, to an abstract definition as a list of things, and that list obeys two properties:
# 1. Multiplication by a scalor
# 2. Addition with another vector
#
# **Quiz:**
#
# Nothing worth noting here, only very basic known stuff were covered in it.

# %% [markdown]
# ## **Week Two**
#
# In this module, we look at operations we can do with vectors - finding the modulus (size), angle between vectors (dot or inner product) and projections of one vector onto another. We can then examine how the entries describing a vector will depend on what vectors we use to define the axes - the basis. That will then let us determine whether a proposed set of basis vectors are what's called 'linearly independent.' This will complete our examination of vectors, allowing us to move on to matrices in module 3 and then start to solve linear algebra problems.
#
# **Learning Objectives:**
# * Calculate basic operations (dot product, modulus, negation) on vectors
# * Calculate a change of basis
# * Recall linear independence
# * Identify a linearly independent basis and relate this to the dimensionality of the space

# %% [markdown]
# ### **Finding The Size of a Vector, Its Angle, and Projection**
#
# **Video:**
#
# Nothing worth mentioning here. Pretty basic stuff.
#
# **Quiz:**
#
# I will solve it by code to practice how things are calculated by code rather than hand

# %% [markdown]
# ![image.png](attachment:0024fa14-046d-4ddc-b9c1-08bfbe7e8dd4.png)

# %%
q1_solution = np.linalg.norm(np.array([1,3,4,2]))
q1_solution
# Out:
# 5.477225575051661

# %% [markdown]
# ![image.png](attachment:1105bc82-5fab-44da-89e1-693fa167c24d.png)

# %%
r = np.array([-5,3,2,8])
s = np.array([1,2,-1,0])

q2_solution = np.dot(r,s)
q2_solution
# Out:
# -1

# %% [markdown]
# ![image.png](attachment:35599c1d-4a6d-47e0-9f2a-c736734f4396.png)

# %%
r = np.array([3,-4,0])
s = np.array([10,5,-6])

q3_solution = np.dot(r,s) / np.linalg.norm(r)                                  # Scalar projection of s onto r formula
q3_solution
# Out:
# 2.0

# %% [markdown]
# ![image.png](attachment:540ae3dc-8d0d-4562-80ca-2e9041bbdb33.png)

# %%
r = np.array([3,-4,0])
s = np.array([10,5,-6])

q4_solution = (r * np.dot(r,s)) / ((np.linalg.norm(r))**2)                     # Vector projection of s onto r formula
q4_solution
# Out:
# array([ 1.2, -1.6,  0. ])

# %% [markdown]
# ![image.png](attachment:194773be-125d-4e23-92bc-03306d97b243.png)

# %%
# In theory |a+b| <= |a| + |b|. Therefore, only the first two options are viable:

a = np.array([3,0,4])
b = np.array([0,5,12])
c = a + b

np.linalg.norm(c) < (np.linalg.norm(a) + np.linalg.norm(b))                   # The first option is true.
# Out:
# True

# %% [markdown]
# ![image.png](attachment:9d903634-e725-4e52-8487-330d10085014.png)

# %% [markdown]
# ### **Changing The Reference Frame & Essence Of Linear Algebra Series**
#
# **Videos:**
# Here the videos are all the coursera videos under this title and the first two videos of the essence of linear algebra series. A couple of eye opening viewpoints were coverd here, and I will mention them briefly, and do some examples to show the concepts. These ideas are:
#
# 1. You Can pick any arbitary basis vectors and write any vector in space using those basis vectors under the conditions that there are as many linearly independent basis vectors as the dimensions of the vector of question, and that they span the space.
#
# 2. You can look at a vector from three perspectives:
#     1. The physics point of view: A thing in the physical space with a specific magnitude and direction.
#     2. The computer science point of view: An ordered list of things.
#     3. The mathematics point of view: Something that satisfy two properties: Vector addition, and scalar multiplication.
#
#
# 3. The basis set: some number of linearly independent vectors, and that number is the number of dimensions in that space. _Note that the choice of the basis set isn't unique._
#
# 4. The span: All the possible vectors generated from a linear combination of the basis set.
#
# **_Note that the vectors in the basis set only need to satisfy linear independence, but choosing an orthonormal basis set simplifies the transformations alot._**
#
# Here is an example:

# %%
def draw_vector(org1x,org1y,vec, col,org2x,org2y,vec2,col2,org3x,org3y,vec3,col3,
                 org4x,org4y,vec4,col4,org5x,org5y,vec5,col5):
    '''This Function plots five two dimensional vectors by taking their components and their colors'''
    
    plt.figure()
    ax = plt.gca()
    
    ax.quiver(org1x,org1y,vec[0],vec[1], color=col, angles='xy', scale_units='xy',scale=1)
    ax.quiver(org2x,org2y,vec2[0],vec2[1], color=col2, angles='xy', scale_units='xy',scale=1)
    ax.quiver(org3x,org3y,vec3[0],vec3[1], color=col3, angles='xy', scale_units='xy',scale=1)
    ax.quiver(org4x,org4y,vec4[0],vec4[1], color=col4, angles='xy', scale_units='xy',scale=1)
    ax.quiver(org5x,org5y,vec5[0],vec5[1], color=col5, angles='xy', scale_units='xy',scale=1)
    
    ax.set_xlim([-5,5])
    ax.set_ylim([-5,5])
    plt.grid()
    
draw_vector(0,0,[1,0],'k',0,0,[0,1],'k', 0,0,[3,4], 'r',0,0,[2,1],'b',0,0,[-2,4],'b')  # Here you give the tail, each basis component and the color,
                                                                                       # respectively for each vector

# %% [markdown]
# The two black vectors are an example of a basic basis set, which consists of two unit vectores, one horizontal and one vertical. The red vector is a vector in space that is represented as a scaled sum of the basis vectors. This vector can be represented as the sum of [3,0] and [0,4] which are 3 times the horizantal basis vector and four times the vertical one. These Two vectors come from projecting the red vector onto each basis vector, The resulting two vectors are shown in yellow below. I moved the vertical one three units to the right to show that their sum results in the red vector.

# %%
draw_vector(0,0,[1,0],'k',0,0,[0,1],'k', 0,0,[3,4], 'r',0,0,[3,0],'y',3,0,[0,4],'y')

# %% [markdown]
# What the above showed is that the red vector can be represented by a linear sum of the basis vectors, i.e, the basis vectors span it. Since the choice of this basis vectors was claimed not to be unique, I will use the two blue vectors as a basis set, and represent the red vector using them.

# %%
# Vector projecting the red vector onto the blue vectors:

red = np.array([3,4])
shorter_blue = np.array([2,1])
longer_blue = np.array([-2,4])

proj_short = (np.dot(red,shorter_blue) * shorter_blue) / (np.linalg.norm(shorter_blue)**2)
proj_long = (np.dot(red,longer_blue) * longer_blue) / (np.linalg.norm(longer_blue)**2)

draw_vector(0,0,[1,0],'k',0,0,[0,1],'k', 0,0,[3,4], 'r',0,0,[proj_short[0],proj_short[1]],'y',
            proj_short[0],proj_short[1],[proj_long[0],proj_long[1]],'y')

# %% [markdown]
# Note that we were also able to represent the red vector as a sum of the two blue basis vectors, i.e, the blue vectors span it as well and can be used as a bisis set. Note that the two blue vectors are orthogonal, and that's why the projection of the red vector onto them resulted in the red vector itself after addition. This is not the case for non-orthogonal vectors, and for that some other scaling and addition may be required, but that doesn't mean that we can't represent the red vector using them, it just means that it needs more steps. Try changing the shorter blue to [3,1] and notice the need for scaling. For a set of vectors to be a basis set, you only need to meet two conditions:
# 1. linear independence
# 2. Spans the space

# %%
shorter_blue = np.array([3,1])
proj_short = (np.dot(red,shorter_blue) * shorter_blue) / (np.linalg.norm(shorter_blue)**2)

draw_vector(0,0,[1,0],'k',0,0,[0,1],'k', 0,0,[3,4], 'r',0,0,[proj_short[0],proj_short[1]],'y',
            proj_short[0],proj_short[1],[proj_long[0],proj_long[1]],'y')

# %% [markdown]
# * Here is how projecting onto non-orthognal basis set and just adding them results to. Note how you need some scaling to represent the red vector.
# * This is why orthogonal vectors are typically used as a basis set.

# %% [markdown]
# **Quizes:**
# There are two quizes, and here is the first one:
# I will solve it by code to practice how things are calculated by code rather than hand.

# %% [markdown]
# ![image.png](attachment:cdaf06d1-5754-4392-bd20-ceda0532d8fc.png)

# %% [markdown]
# The red vector written in terms of the new basis vectors means a scalar multiplied by the unit vector of a direction, such that the red vector [3,5] means 3i+5j we want [r1,r2] such that r1b1+r2b2 results in the red vector. Note that the last b1, b2 are unit vectors. r1b1 and b2r2 are the vector projections of the red vector onto the new basis vectors. THerefore, to calculate r1 and r2 we just need to ommit the unit vectors from the vector projection formula since we will do it anyway when representing the red vector in terms of the new basis vectors.

# %%
v = np.array([5,-1])
b1 = np.array([1,1])
b2 = np.array([1,-1])

projb1 = (np.dot(v,b1))/(np.linalg.norm(b1)**2)
projb2 = (np.dot(v,b2))/(np.linalg.norm(b2)**2)

print(projb1)
print(projb2)
# Out:
# 1.9999999999999996
# 2.9999999999999996

# %% [markdown]
# And here is a graphical representaion:

# %%
draw_vector(0,0,[1,0],'k',0,0,[0,1],'k', 0,0,[5,-1], 'r',0,0,[1,1],'b',0,0,[1,-1],'b')     # Basic basis set

# %%
# Vector projecting the red vector onto the blue vectors:

red = np.array([5,-1])
shorter_blue = np.array([1,1])
longer_blue = np.array([1,-1])

proj_short = (np.dot(red,shorter_blue) * shorter_blue) / (np.linalg.norm(shorter_blue)**2)           #The new basis set
proj_long = (np.dot(red,longer_blue) * longer_blue) / (np.linalg.norm(longer_blue)**2)

draw_vector(0,0,[1,0],'k',0,0,[0,1],'k', 0,0,[5,-1], 'r',0,0,[proj_short[0],proj_short[1]],'y',
            proj_short[0],proj_short[1],[proj_long[0],proj_long[1]],'y')

# %% [markdown]
# Questions 2-5 are the same as the first question, hence I will solve only the last one since it covers them all:
# ![image.png](attachment:bf782680-b063-4b3a-acd4-d29cb9771e5c.png)

# %%
v = np.array([1,1,2,3])
b1 = np.array([1,0,0,0])
b2 = np.array([0,2,-1,0])
b3 = np.array([0,1,2,0])
b4 = np.array([0,0,0,3])

projb1 = (np.dot(v,b1))/(np.linalg.norm(b1)**2)
projb2 = (np.dot(v,b2))/(np.linalg.norm(b2)**2)
projb3 = (np.dot(v,b3))/(np.linalg.norm(b3)**2)
projb4 = (np.dot(v,b4))/(np.linalg.norm(b4)**2)

print(projb1)
print(projb2)
print(projb3)
print(projb4)
# Out:
# 1.0
# 0.0
# 0.9999999999999998
# 1.0

# %% [markdown]
# **The second quiz:**
# The first two questions are so obvious to the point that I did them in my mind. Therefore, here is the third one:
# ![image.png](attachment:537a4105-8a76-4ef3-b7e8-aa332ec3ae4b.png)

# %%
# Let me define the vectors first:
a = np.array([2,2])
b = np.array([1,-2])
c = np.array([-1,0])

# This is a system of two linear equations:
# 1. q1-q2 = 2
# 2. -2q1 = 2

coeffecients = np.array([[1,-1],[-2,0]])
values = np.array([2,2])

np.linalg.solve(coeffecients, values)
# Out:
# array([-1., -3.])

# %% [markdown]
# The last three questions are obvious as well.For the first one, it is apparent that no matter how you try you will never be able to represent any of them as a scaled sum of the others.
# The second one a = -b-c, and the last one c = 2a-b so they're linearly dependant, and hence only span two dimensions.

# %% [markdown]
# ### **Doing Some Real-World Vectors Examples**
# ![image.png](attachment:4f3385bb-11ea-4572-ac2a-5d211229b3e5.png)

# %% [markdown]
# This is a simple vector projection question, the answer is the vector projection of the velocity vector onto the direction vector:

# %%
velocity = np.array([1,2])
direction = np.array([1,1])

result = (np.dot(velocity,direction) * direction) / (np.linalg.norm(direction)**2)
result
# Out:
# array([1.5, 1.5])

# %% [markdown]
# ![image.png](attachment:e208d43f-ffe2-43d4-a743-c4b8ee75a2bd.png)

# %% [markdown]
# This is the same as the last one but with taking the norm of the result:

# %%
velocity = np.array([2,1])
direction = np.array([3,-4])

result = (np.dot(velocity,direction) * direction) / (np.linalg.norm(direction)**2)
np.linalg.norm(result)
# Out:
# 0.4

# %% [markdown]
# ![image.png](attachment:8395f4ce-f9e9-4510-b0fc-b623fd3cd0a9.png)

# %% [markdown]
# Here we want to represent the vector v with the other vectors instead of the standard basis set, and to do that, we need to get the size of the vector project of v onto each one of them:

# %%
v = np.array([-4,-3,8])
b1 = np.array([1,2,3])
b2 = np.array([-2,1,0])
b3 = np.array([-3,-6,5])

proj_b1 = np.dot(v,b1) / (np.linalg.norm(b1)**2)
proj_b2 = np.dot(v,b2) / (np.linalg.norm(b2)**2)
proj_b3 = np.dot(v,b3) / (np.linalg.norm(b3)**2)

result = np.array([proj_b1, proj_b2, proj_b3])
result
# Out:
# array([1., 1., 1.])

# %% [markdown]
# ![image.png](attachment:fc193ff3-8b41-4a30-97ee-5fd477783a92.png)

# %% [markdown]
# c = b-2a so no

# %% [markdown]
# ![image.png](attachment:846b4b5a-56d2-43ba-9665-c74e0caffd1b.png)

# %% [markdown]
# Displacement = velocity * time = end position - starting position
#
# result = end position = velocity * time + starting position

# %%
velocity = np.array([-1,2,-3])
time = 2
starting_position = np.array([3,2,4])

result = velocity * time + starting_position
result
# Out:
# array([ 1,  6, -2])

# %% [markdown]
# ### **Gilbert Strang's Linear Algebra Book**
# I will study multiple books alongside with the online courses to be more grounded on my theoritical understanding, and this is one of them. Here I will go through the first two sections in the first chapter to cach up with the course, and here is what I found worth noting after doing just that:
#
# 1. An n dimensional vector can be written as (a1,a2,a3,,,,,an) to save space
# 2. The zero vector is always present because you can always scale the vectors in the basis set by zero.
# 3.
#
# ![image.png](attachment:5128685b-061b-46fc-8a4f-217640cb3e03.png)

# %% [markdown]
# To demonstrate how these linear combinationas span their correspondoing space, I will plot the second point:

# %%
colors = 'bgrcmykw'

def draw_vector():
    '''This function draws a randomely generated two dimensional vector in the two dimensional space
       resulting as a linear combination of two two dimensional vectors'''
    ax = plt.gca()
    x = np.array([np.random.randint(-40,40), np.random.randint(-40,40)], dtype=float)              # First two dimensional vector
    y = np.array([np.random.randint(-40,40), np.random.randint(-40,40)], dtype=float)              # Second two dimensional vector
    result = np.random.randint(-2,2) * x + np.random.randint(-2,2) * y                             # Their linear combination
    c = np.random.randint(0,8)
    ax.quiver(result[0], result[1], color=colors[c], angles = 'xy', scale_units='xy', scale=1)

# %%
for i in range(500):
    draw_vector()
plt.xlim([-50,50])
plt.ylim([-50,50])
plt.grid()
